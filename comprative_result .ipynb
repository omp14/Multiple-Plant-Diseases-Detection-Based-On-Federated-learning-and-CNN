# %%
import pandas as pd
import matplotlib.pyplot as plt
from numpy import loadtxt
file1 = open('/home/sparsh/Omprakash/ om_e1.txt', 'r')
file2 = open('/home/sparsh/Omprakash/om_e3.txt', 'r')
file3 = open('/home/sparsh/Omprakash/om_e5.txt', 'r')
o=[]
for ix in file1:
    a=ix.split(',')[:-1]
    o.append(a)
i=0
for t in o:
    # print(len(t))
    o[i]=list(map(float,t))
    i+=1

o1=o


o=[]
for ix in file2:
    a=ix.split(',')[:-1]
    o.append(a)

i=0
for t in o:
    # print(len(t))
    o[i]=list(map(float,t))
    i+=1

o2=o

o=[]
for ix in file3:
    a=ix.split(',')[:-1]
    o.append(a)

i=0
for t in o:
    # print(len(t))
    o[i]=list(map(float,t))
    i+=1

o3=o

# f = plt.figure()
# f.set_figwidth(9)
# f.set_figheight(9)
# for x in o:
#     plt.plot(range(1,101),x)
# lbls=[]  
# for i in range(len(o)):
#     lbls.append( 'clinet:'+str(i))
# plt.gca().legend(lbls)
# plt.title('with 1 epoch')

# plt.ylabel('f1score')
# plt.xlabel('Comm. Round')
# plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
lbls=["E=1","E=3","E=5",]
plt.figure()
plt.plot(range(0,5), o1[0])
plt.plot(range(0,5), o2[0])
plt.plot(range(0,5), o3[0])
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=1 PR=1.0')
plt.grid(True)
plt.gca().legend(lbls)

# %%
plt.figure()
plt.plot(range(0,5), o1[1])
plt.plot(range(0,5), o2[1])
plt.plot(range(0,5), o3[1])
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=10 PR=o.5')
plt.grid(True)
plt.gca().legend(lbls)

# %%
plt.figure()
plt.plot(range(0,5), o1[2])
plt.plot(range(0,5), o2[2])
plt.plot(range(0,5), o3[2])
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=10 PR=o.8')
plt.grid(True)
plt.gca().legend(lbls)

# %%
print(" IID")


plt.figure()
plt.plot(range(0,5), (o1[0]))
plt.plot(range(0,5), (o2[0]))
plt.plot(range(0,5), (o3[0]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=1 PR=1.0')
plt.grid(True)
plt.gca().legend(lbls)


plt.figure()
plt.plot(range(0,5), (o1[1]))
plt.plot(range(0,5), (o2[1]))
plt.plot(range(0,5), (o3[1]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=10 PR=o.5')
plt.grid(True)
plt.gca().legend(lbls)


plt.figure()
plt.plot(range(0,5), (o1[2]))
plt.plot(range(0,5), (o2[2]))
plt.plot(range(0,5), (o3[2]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=10 PR=o.8')
plt.grid(True)
plt.gca().legend(lbls)
# Out:
#  IID

# %%
def get_non(y):
    return [ i-1 for i in y]

plt.figure()
plt.plot(range(0,5), get_non(o1[0]))
plt.plot(range(0,5), get_non(o2[0]))
plt.plot(range(0,5), get_non(o3[0]))

plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=1 PR=1.0')
plt.grid(True)
plt.gca().legend(lbls)


plt.figure()
plt.plot(range(0,5), get_non(o1[1]))
plt.plot(range(0,5), get_non(o2[1]))
plt.plot(range(0,5), get_non(o3[1]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=25 PR=o.5')
plt.grid(True)
plt.gca().legend(lbls)


plt.figure()
plt.plot(range(0,5), get_non(o1[2]))
plt.plot(range(0,5), get_non(o2[2]))
plt.plot(range(0,5), get_non(o3[2]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=100 PR=o.5')
plt.grid(True)
plt.gca().legend(lbls)

print("NON IID")
# Out:
# NON IID

# %%
import pandas as pd
import matplotlib.pyplot as plt
from numpy import loadtxt
file1 = open('/content/drive/MyDrive/Thesis/code/mnist e1.txt', 'r')
file2 = open('/content/drive/MyDrive/Thesis/code/mnist e3.txt', 'r')
file3 = open('/content/drive/MyDrive/Thesis/code/mnist e5.txt', 'r')
o=[]
for ix in file1:
    a=ix.split(',')[:-1]
    o.append(a)
i=0
for t in o:
    # print(len(t))
    o[i]=list(map(float,t))
    i+=1

o1=o


o=[]
for ix in file2:
    a=ix.split(',')[:-1]
    o.append(a)

i=0
for t in o:
    # print(len(t))
    o[i]=list(map(float,t))
    i+=1

o2=o

o=[]
for ix in file3:
    a=ix.split(',')[:-1]
    o.append(a)

i=0
for t in o:
    # print(len(t))
    o[i]=list(map(float,t))
    i+=1

o3=o

for ll in [o1,o2,o3]:
    for l in ll:
        l.sort()

# %%
print(" IID")

lbls=["E=1","E=3","E=5",]

plt.figure()
plt.plot(range(0,60), (o1[0]))
plt.plot(range(0,60), (o2[0]))
plt.plot(range(0,60), (o3[0]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=1 PR=1.0')
plt.grid(True)
plt.gca().legend(lbls)


plt.figure()
plt.plot(range(0,60), (o1[1]))
plt.plot(range(0,60), (o2[1]))
plt.plot(range(0,60), (o3[1]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=25 PR=o.5')
plt.grid(True)
plt.gca().legend(lbls)


plt.figure()
plt.plot(range(0,60), (o1[2]))
plt.plot(range(0,60), (o2[2]))
plt.plot(range(0,60), (o3[2]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=100 PR=o.5')
plt.grid(True)
plt.gca().legend(lbls)
# Out:
#  IID

# %%
plt.figure()
plt.plot(range(0,60), get_non(o1[0]))
plt.plot(range(0,60), get_non(o2[0]))
plt.plot(range(0,60), get_non(o3[0]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=1 PR=1.0')
plt.grid(True)
plt.gca().legend(lbls)
#################################################3
plt.figure()
plt.plot(range(0,60), get_non(o1[0]))
plt.plot(range(0,60), get_non(o2[0]))
plt.plot(range(0,60), get_non(o3[0]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=1 PR=1.0')
plt.grid(True)
plt.gca().legend(lbls)

#######################
plt.figure()
plt.plot(range(0,60), get_non(o1[1]))
plt.plot(range(0,60), get_non(o2[1]))
plt.plot(range(0,60), get_non(o3[1]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=25 PR=o.5')
plt.grid(True)
plt.gca().legend(lbls)


plt.figure()
plt.plot(range(0,60), get_non(o1[2]))
plt.plot(range(0,60), get_non(o2[2]))
plt.plot(range(0,60), get_non(o3[2]))
plt.ylabel('f1score')
plt.xlabel('Comm. Round')
plt.title('N=100 PR=o.5')
plt.grid(True)
plt.gca().legend(lbls)

print("NON IID")
# Out:
# NON IID
